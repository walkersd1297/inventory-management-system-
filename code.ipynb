# %%
import json  # import json 
import time

#original data in the dictionary
data = {194501: {"name": "Kit-Kat", "Price": 10, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 20, "Expiration Date": "10-10-2021"},
        194502: {"name": "Kit-Kat", "Price": 25, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 50, "Expiration Date": "10-10-2021"},
        194503: {"name": "Kit-Kat", "Price": 50, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 00, "Expiration Date": "10-10-2021"},
        194504: {"name": "Maggi-Noodles", "Price": 10, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 50, "Expiration Date": "10-10-2021"},
        194505: {"name": "Maggi-Noodles", "Price": 50, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 200, "Expiration Date": "10-10-2021"},
        194506: {"name": "Munch", "Price": 10, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 20, "Expiration Date": "10-10-2021"},
        194507: {"name": "Munch", "Price": 20, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 50, "Expiration Date": "10-10-2021"},
        194508: {"name": "Milky-Bar", "Price": 10, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 20, "Expiration Date": "10-10-2021"},
        194509: {"name": "Milky-Bar", "Price": 20, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 50, "Expiration Date": "10-10-2021"},
        194510: {"name": "Milk-Maid", "Price": 128, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 50, "Expiration Date": "10-10-2021"},
        194511: {"name": "Bar-One", "Price": 10, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 20, "Expiration Date": "10/10/2021"},
        194512: {"name": "Nestea", "Price": 180, "Quantity": 100, "Brand Name": "Nestle", "Flavour": "None", "weight": 500, "Expiration Date": "10-10-2021"},
        194513: {"name": "Cadbury Dairy-Milk", "Price": 5, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "None", "weight": 10, "Expiration Date": "10-10-2021"},
        194514: {"name": "Cadbury Dairy-Milk", "Price": 10, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "None", "weight": 20, "Expiration Date": "10-10-2021"},
        194515: {"name": "Cadbury Dairy-Milk", "Price": 50, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "None", "weight": 70, "Expiration Date": "10-10-2021"},
        194516: {"name": "Cadbury Dairy_Milk Silk", "Price": 70, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "None", "weight": 100, "Expiration Date": "10-10-2021"},
        194517: {"name": "Dairy-Milk Silk Almond", "Price": 80, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "Almond", "weight": 100, "Expiration Date": "10-10-2021"},
        194518: {"name": "Dairy-Milk Silk Bubbly", "Price": 90, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "Bubbly", "weight": 100, "Expiration Date": "10-10-2021"},
        194519: {"name": "Dairy-Milk Silk Fruit & Nut", "Price": 90, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "Fruit & Nut", "weight": 100, "Expiration Date": "10-10-2021"},
        194520: {"name": "Dairy-Milk Silk Roast Almond", "Price": 90, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "Roast Almond", "weight": 100, "Expiration Date": "10-10-2021"},
        194521: {"name": "Dairy-Milk Silk Caramello", "Price": 100, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "Caramello", "weight": 100, "Expiration Date": "10-10-2021"},
        194522: {"name": "5 Star", "Price": 5, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "None", "weight": 10, "Expiration Date": "10-10-2021"},
        194523: {"name": "5 Star", "Price": 10, "Quantity": 100, "Brand Name": "Cadbury", "Flavour": "None", "weight": 20, "Expiration Date": "10-10-2021"},
        194524: {"name": "Double-Mint", "Price": 10, "Quantity": 100, "Brand Name": "", "Flavour": "None", "weight": 10, "Expiration Date": "10-10-2021"},
        194525: {"name": "Snickers", "Price": 10, "Quantity": 100, "Brand Name": "Mars", "Flavour": "None", "weight": 10, "Expiration Date": "10-10-2021"},
        194526: {"name": "Snickers", "Price": 25, "Quantity": 100, "Brand Name": "Mars", "Flavour": "None", "weight": 20, "Expiration Date": "10-10-2021"},
        194527: {"name": "Amul Butter", "Price": 50, "Quantity": 100, "Brand Name": "Amul", "Flavour": "None", "weight": 100, "Expiration Date": "10-10/2021"},
        194528: {"name": "Amul Ghee", "Price": 200, "Quantity": 100, "Brand Name": "Amul", "Flavour": "None", "weight": 500, "Expiration Date": "10-10-2021"},
        194529: {"name": "Amul Dahi", "Price": 40, "Quantity": 100, "Brand Name": "Amul", "Flavour": "None", "weight": 500, "Expiration Date": "10-10-2021"},
        194530: {"name": "Amul Paneer", "Price": 70, "Quantity": 100, "Brand Name": "Amul", "Flavour": "None", "weight": 100, "Expiration Date": "10-10-2021"}}

# converting original data (dictionary) into string
data_in_str = json.dumps(data)

    #creating a data text file for the original data
with open("data.json", "w") as f:
    data_in_file = f.write(data_in_str) #write the string data inside the data.txt file 

    #reading the data from the data.txt
with open("data.json", "r") as f:
    data_in_file_read = f.read() #read tyhe data from the data.txt
    data = json.loads(data_in_file_read) #converting string into dictionary by creating a file 

sum = 0 #initialising total sum
tot_weight = 0.0 #initialising total weight 
print('''Following operations can be performed :
     Type add in the product id when asked to add the given data into inventory 
     Type bill in the product id after buying the products for total amount
     Else type the pduct id of product which user want to purchase''')
while True: 
    prodId = input("Enter the Product ID : ") # asking the product id from the user

    if prodId in data.keys():
        noOfQuantity = int(input("Enter the number of quantity : ")) # asking number of quantity from the user
        # Entering the data for the left quantities in different file 
        quantity_left = int(data[prodId]['Quantity']) - noOfQuantity
        if(quantity_left > noOfQuantity):
            print("************************************************")
            print(f"Name of Item Purchased: {data[prodId]['name']}")
            print(f"Price of 1 {data[prodId]['name']}: {data[prodId]['Price']}")
            print(f"Quantity of {data[prodId]['name']}: {noOfQuantity}")
            print(f"Flavour: {data[prodId]['Flavour']}")
            print(f"Weight: {data[prodId]['weight']} grams")
            print(f"Expiration Date : {data[prodId]['Expiration Date']}")
            print(f"Total amount of the {data[prodId]['name']} purchased: {(data[prodId]['Price'])*(noOfQuantity)}")
            print("*************************************************\n") 
            with open("sales.json" , "a") as f:
                saleDone = f"name: {data[prodId]['name']} \n  Price:{data[prodId]['Price']} \n  No of quantity Sold:{str(noOfQuantity)} \n  No of Quantity Left:{str(quantity_left)} \n "
                f.write(saleDone)
        else:
            print(f"Only {data[prodId]['Quantity']} products are left ")  #Tells us if the quantity left is lesser than the number of quantity asked by the user
            break
    
    if (prodId == 'add'):
        purchase_prodId = input("Enter the purchase product's id : ")
        purchase_name = input("Enter the purchase product' name : ")
        purchase_price = int(input("Enter the purchase product's price : "))
        purchase_quantity = int(input("Enter the purchase product's quantity : "))
        purchase_brand = input("Enter the purchase product's brand : ")
        purchase_flavour = input("Enter the purchase product's flavour : ")
        purchase_weight = int(input("Enter the purchase product's weight : "))
        purchase_expiry = input("Enter the purchase products's expiry date : ")
        data[prodId] = {"name": purchase_name , "Price": purchase_price ,"Quantity": purchase_quantity ,"Brand Name": purchase_brand ,"Flavour": purchase_flavour ,"weight": purchase_weight ,"Expiration Date": purchase_expiry}
        updated_data = json.dumps(data)
        with open("data.json" , "w") as f:
            f.write(updated_data)
        break
    
    if(prodId == 'bill'):
        break

    sum += (data[prodId]['Price'])*(noOfQuantity)   #Total Billing Amount 
    tot_weight += ((data[prodId]['weight'])/1000)   #Total Net Weight

print(f"Net Weight : {tot_weight} kgms\n")
print(f"\n Billing Amount : {sum}")  
    
print(f"\n\nDated: {time.ctime()}")    
print("**************************************\n\n")
print("Thank You for shopping with us ,Have a nice day ")
print("*****************************************")
# Out:
# Following operations can be performed :
#      Type add in the product id when asked to add the given data into inventory
#      Type bill in the product id after buying the products for total amount
#      Else type the pduct id of product which user want to purchase
# Enter the Product ID : 194502
# Enter the number of quantity : 10
# ************************************************
# Name of Item Purchased: Kit-Kat
# Price of 1 Kit-Kat: 25
# Quantity of Kit-Kat: 10
# Flavour: None
# Weight: 50 grams
# Expiration Date : 10-10-2021
# Total amount of the Kit-Kat purchased: 250
# *************************************************
#
# Enter the Product ID : 194524
# Enter the number of quantity : 15
# ************************************************
# Name of Item Purchased: Double-Mint
# Price of 1 Double-Mint: 10
# Quantity of Double-Mint: 15
# Flavour: None
# Weight: 10 grams
# Expiration Date : 10-10-2021
# Total amount of the Double-Mint purchased: 150
# ...
